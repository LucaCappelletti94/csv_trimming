# %%
from random_csv_generator import random_csv
from ugly_csv_generator import uglify
from csv_trimming import trim_csv

# %%
csv = random_csv(100)
ugly = uglify(csv, duplicate_schema=False, empty_rows=False, seed=29)
# Out:
# HBox(children=(IntProgress(value=0, description='Adding empty columns', max=4, style=ProgressStyle(description…

# %%
trim_csv(ugly)
# Out:
#                   region                province   surname  \
# 0                Toscana  Massa          Carrara     Costa
# 1                  Lazio                    Roma  Paolucci
# 2                  Lazio                    Roma  Lombardi
# 3               Piemonte                  Torino   Sartori
# 4               Piemonte                  Torino   Mancini
# ..                   ...                     ...       ...
# 95  Emilia       Romagna                Piacenza     Rossi
# 96               Toscana                   Lucca    Galati
# 97                Marche         Ascoli   Piceno    Alaimo
# 98              Calabria                 Crotone  Esposito
# 99              Piemonte                  Torino     Rossi
#
#                   name sex                 birth_municipality  \
# 0                Piera   F                             Aidone
# 1               Sergio   M                             Toffia
# 2             Vittorio   M  Poggio          A          Caiano
# 3               Giulia   F                             Sarego
# 4                Eider   F                   Barbarano Romano
# ..                 ...  ..                                ...
# 95              Chiara   F                              Uscio
# 96  Claudio      Maria   M                            Spadola
# 97             Susanna   F                    Lucca    Sicula
# 98             Luciano   M                            Cellole
# 99             Edoardo   M                          Viareggio
#
#           birth_province birth_region birth_cap birth_province_code  \
# 0                   Enna      Sicilia     94010                  EN
# 1                  Rieti        Lazio     02039                  RI
# 2                  Prato      Toscana     59016                  PO
# 3                Vicenza       Veneto     36040                  VI
# 4                Viterbo        Lazio     01010                  VT
# ..                   ...          ...       ...                 ...
# 95                Genova      Liguria     16036                  GE
# 96  Vibo        Valentia     Calabria     89822                  VV
# 97             Agrigento      Sicilia     92010                  AG
# 98               Caserta     Campania     81030                  CE
# 99                 Lucca      Toscana     55049                  LU
#
#      birthdate                                       address house_number  \
# 0   1946-04-13                            Via       Stazione           77
# 1   1954-07-30                  Via   Madonna   Del   Riposo          125
# 2   1923-08-14                     Via    Val    Di    Cogne            4
# 3   1957-03-17                         Piazza        Agnelli          1/B
# 4   1960-02-05  Corso       Vittorio       Emanuele       Ii           61
# ..         ...                                           ...          ...
# 95  1995-01-13                             Via          Roma           15
# 96  1939-11-23                          Piazza  San  Michele           38
# 97  1962-05-19                         Via       Castiglione           15
# 98  1992-05-05                      Via    Interna    Marina           20
# 99  1921-06-28                        Corso          Potenza           92
#
#       cap                     municipality province_code    codice_fiscale  \
# 0   54014  Casola       In       Lunigiana            MS  CSTPRI46D53A098B
# 1     165                             Roma            RM  PLCSRG54L30L189M
# 2     141                             Roma            RM  LMBVTR23M14G754L
# 3   10058                        Sestriere            TO  SRTGLI57C57I430Z
# 4   10010           Albiano        D'ivrea            TO  MNCDRE60B45A628P
# ..    ...                              ...           ...               ...
# 95  29010                       Calendasco            PC  RSSCHR95A53L507Y
# 96  55100                            Lucca            LU  GLTCDM39S23I884M
# 97  63017            Porto   San   Giorgio            AP  LMASNN62E59E714V
# 98  88900                          Crotone            KR  SPSLCN92E05M262L
# 99  10149                           Torino            TO  RSSDRD21H28L833G
#
#             total_debit           payed_debit
# 0         46.739,00   €       17.924,00     €
# 1           75.746,00 €      74.623,00      €
# 2   65.089,00         €      63.382,00      €
# 3     32.181,00       €   10.713,00         €
# 4    8.617,00         €           6.109,00  €
# ..                  ...                   ...
# 95          73.706,00 €    57.477,00        €
# 96         79.022,00  €         40.334,00   €
# 97    57.690,00       €           32.754,00 €
# 98          76.527,00 €  24.562,00          €
# 99   8.198,00         €          2.399,00   €
#
# [100 rows x 19 columns]
