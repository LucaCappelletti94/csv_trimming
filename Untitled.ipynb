# %%
from random_csv_generator import random_csv
from ugly_csv_generator import uglify
from csv_trimming import trim_csv
from italian_csv_type_prediction.simple_types.nan_type import NaNType

# %%
csv = random_csv(10)
ugly = uglify(csv, duplicate_schema=False, empty_rows=False, seed=29, )
# Out:
# HBox(children=(IntProgress(value=0, description='Adding empty columns', max=15, style=ProgressStyle(descriptio…

# %%
trim_csv(ugly)
# Out:
#                             region              province    surname  \
# 0                         Sardegna  Olbia    -    Tempio    Torrisi
# 1                        Lombardia                Milano   Gurrieri
# 2                        Lombardia                Varese      Serra
# 3                          Sicilia               Messina    Torrisi
# 4                           Marche              Macerata  Innocenti
# 5                         Sardegna               Sassari     Favaro
# 6                          Sicilia               Catania      Rossi
# 7                        Lombardia                 Lecco     Sucera
# 8                         Calabria   Reggio     Calabria     Galati
# 9  Friuli      Venezia      Giulia                 Udine    Venturi
#
#                name sex                birth_municipality   birth_province  \
# 0  Irene   Caterina   F                          Belpasso          Catania
# 1            Sergio   M         Chiaramonte         Gulfi           Ragusa
# 2            Gloria   F  Monteleone      Rocca      Doria          Sassari
# 3             Salwa   F              Mirabella  Imbaccari          Catania
# 4        Marialuisa   F               Poggio   A   Caiano            Prato
# 5         Robertina   F                         Carbonera          Treviso
# 6             Arjan   M                      Vastogirardi          Isernia
# 7           Michela   F                           Bivongi  Reggio-Calabria
# 8             Palma   F           Monterosso      Calabro  Vibo   Valentia
# 9           Melissa   F                        Malalbergo          Bologna
#
#               birth_region birth_cap birth_province_code   birthdate  \
# 0                  Sicilia     95032                  CT  1937-08-14
# 1                  Sicilia     97012                  RG  1927-09-05
# 2                 Sardegna     07010                  SS  1954-12-25
# 3                  Sicilia     95040                  CT  1968-06-06
# 4                  Toscana     59016                  PO  1980-01-10
# 5                   Veneto     31030                  TV  1979-07-23
# 6                   Molise     86089                  IS  1968-11-10
# 7                 Calabria     89040                  RC  1988-08-04
# 8                 Calabria     89819                  VV  1981-06-19
# 9  Emilia          Romagna     40051                  BO  1986-02-05
#
#                           address house_number    cap  \
# 0                     Piazza Etna            1  07026
# 1          Via        Crescenzago           36  20134
# 2                  Via   Pegoraro           30  21013
# 3                   Via Umberto I          356  98027
# 4                 Via    Calcagni           31  62019
# 5                  Via       Roma           56  07030
# 6     Piazza  Rosario  Bonaccorso            5  95037
# 7                      Via   Roma            1  23875
# 8             Corso   Umberto   I           73  89056
# 9  Via        Della        Chiesa         13/B  33015
#
#                                     municipality province_code  \
# 0                                          Olbia            OT
# 1                                         Milano            MI
# 2                                      Gallarate            VA
# 3                                    Roccalumera            ME
# 4                                       Recanati            MC
# 5                                         Laerru            SS
# 6                    San   Giovanni   La   Punta            CT
# 7                                         Osnago            LC
# 8  Santa          Cristina          D'aspromonte            RC
# 9                          Moggio        Udinese            UD
#
#      codice_fiscale           total_debit          payed_debit
# 0  TRRRCT37M54A766I      16.006,00      €         10.349,00  €
# 1  GRRSRG27P05C612T  58.184,00          €        45.573,00   €
# 2  SRRGLR54T65F542L    55.470,00        €     34.159,00      €
# 3  TRRSLW68H46F231Z      86.336,00      €   50.987,00        €
# 4  NNCMLS80A50G754F  51.174,00          €     15.638,00      €
# 5  FVRRRT79L63B744E         13.625,00   €    10.974,00       €
# 6  RSSRJN68S10L696U   78.612,00         €         75.497,00  €
# 7  SCRMHL88M44A897J           63.552,00 €       21.913,00    €
# 8  GLTPLM81H59F607P     50.302,00       €   34.675,00        €
# 9  VNTMSS86B45E844B       53.217,00     €  24.568,00         €
