# %%
from random_csv_generator import random_csv
from ugly_csv_generator import uglify
from csv_trimming import trim_csv
from italian_csv_type_prediction.simple_types.nan_type import NaNType

# %%
csv = random_csv(10)
ugly = uglify(csv, duplicate_schema=False, empty_rows=False, seed=29, )
# Out:
# HBox(children=(IntProgress(value=0, description='Adding empty columns', max=15, style=ProgressStyle(descriptio…

# %%
trim_csv(ugly)
# Out:
#                region                 province       surname             name  \
# 0               Lazio                     Roma  D'Alessandro           Franco
# 1             Liguria         La        Spezia         Cossu           Franco
# 2              Puglia                   Foggia      Cattaneo          Klodjan
# 3  Emilia     Romagna                    Parma        Alaimo            Anita
# 4            Piemonte                   Torino       Vailati        Gianluigi
# 5           Lombardia                   Milano        Rosati          Tiziana
# 6               Lazio                     Roma        Deiana          Reghina
# 7            Piemonte                   Novara          Mair            Nicol
# 8            Calabria                  Crotone         Manca         Giuseppe
# 9            Calabria  Reggio         Calabria    Ceccarelli  Maria   Iolanda
#
#   sex                   birth_municipality birth_province  \
# 0   M  Anversa        Degli        Abruzzi       L'Aquila
# 1   M                               Laerru        Sassari
# 2   M                              Civenna           Como
# 3   F                            Agrigento      Agrigento
# 4   M           San   Martino   Del   Lago        Cremona
# 5   F                          San Venanzo          Terni
# 6   F                               Borore          Nuoro
# 7   F                                 Gais        Bolzano
# 8   M                               Gergei       Cagliari
# 9   F                              Spoleto        Perugia
#
#                           birth_region birth_cap birth_province_code  \
# 0                              Abruzzo     67030                  AQ
# 1                             Sardegna     07030                  SS
# 2                            Lombardia     22030                  CO
# 3                              Sicilia     92100                  AG
# 4                            Lombardia     26040                  CR
# 5                               Umbria     05010                  TR
# 6                             Sardegna     08016                  NU
# 7  Trentino         Alto         Adige     39030                  BZ
# 8                             Sardegna     08030                  CA
# 9                               Umbria     06049                  PG
#
#     birthdate                          address house_number    cap  \
# 0  1959-02-02                    Via Portuense          425    149
# 1  1955-02-12              Via        Sardegna         19/c  19126
# 2  1947-07-23      Corso   Giacomo   Matteotti          120  71017
# 3  1974-01-04                  Via Xxii Luglio         13/a  43100
# 4  1986-07-14                  Viale    Radich           21  10095
# 5  1972-09-25             Corso       Sempione          141  20025
# 6  1986-08-18                    Via  Flaminia        719/A    191
# 7  1994-11-21       Via   Giuseppe   Garibaldi            4  28069
# 8  1955-03-25         Via   Della   Repubblica            1  88812
# 9  1959-03-07  Piazza        San        Nicola           23  89010
#
#     municipality province_code    codice_fiscale           total_debit  \
# 0           Roma            RM  DLSFNC59B02A318H      17.858,00      €
# 1   La    Spezia            SP  CSSFNC55B12E401V  64.014,00          €
# 2  Torremaggiore            FG  CTTKDJ47L23C754W    23.668,00        €
# 3          Parma            PR  LMANTA74A44A089F      68.282,00      €
# 4     Grugliasco            TO  VLTGLG86L14I007M  40.613,00          €
# 5        Legnano            MI  RSTTZN72P65I381D         56.309,00   €
# 6           Roma            RM  DNERHN86M58B056J   69.641,00         €
# 7        Trecate            NO  MRANCL94S61D860H           39.162,00 €
# 8        Crucoli            KR  MNCGPP55C25D982F     11.733,00       €
# 9      Varapodio            RC  CCCMLN59C47I921Q       18.726,00     €
#
#            payed_debit
# 0          3.053,00  €
# 1        26.826,00   €
# 2      4.718,00      €
# 3   56.200,00        €
# 4     14.379,00      €
# 5    28.974,00       €
# 6         39.506,00  €
# 7          839,00    €
# 8    4.338,00        €
# 9  17.582,00         €
